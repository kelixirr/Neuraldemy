# %% [markdown]
# <a href="https://colab.research.google.com/github/kelixirr/Complete-Machine-Learning-And-Data-Science-Course/blob/main/Matplotlib_Visualization_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Matplotlib: Visualization with Python For Data Science And Machine Learning
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# - Create publication quality plots.
# - Make interactive figures that can zoom, pan, update.
# - Customize visual style and layout.
# - Export to many file formats.
# - Embed in JupyterLab and Graphical User Interfaces.
# - Use a rich array of third-party packages built on Matplotlib.
#
# ___
# This tutorial was designed by Odist Academy so make sure to register to our course for full access: https://pages.razorpay.com/odist-academy-data-science
# ___

# %%
# Importing all the necessary libraries 

import matplotlib as mpl
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# ## Components of Matplotlip Figure
# Please take out 10-15 mins to understand this image carefully.

# %% [markdown]
# ![anatomy.webp](data:image/webp;base64,...)

# %% [markdown]
# ## Figure
# The whole figure. The Figure keeps track of all the child Axes, a group of 'special' Artists (titles, figure legends, colorbars, etc), and even nested subfigures.

# %%
# create a new figure with no axes 
fig = plt.figure();

# %%
fig, ax = plt.subplots(); # figure with single axes

# %%
fig, axs = plt.subplots(2, 2); #a figure with a 2x2 grid of Axes: You can enter single or two values

# %% [markdown]
# ## Axes And Axis
# An Axes is an Artist attached to a Figure that contains a region for plotting data, and usually includes two (or three in the case of 3D) Axis objects (be aware of the difference between Axes and Axis) that provide ticks and tick labels to provide scales for the data in the Axes. Each Axes also has a title (set via set_title()), an x-label (set via set_xlabel()), and a y-label set via set_ylabel()).
#
# __
#
# Axis:
# These objects set the scale and limits and generate ticks (the marks on the Axis) and ticklabels (strings labeling the ticks).

# %% [markdown]
# Basically, everything visible on the Figure is an Artist (even Figure, Axes, and Axis objects).

# %% [markdown]
# ## Tow ways to create Grapghs: OO & PyPlot
# There are two ways to create graphs using object oriented style or Pyplot but OO is preferred by us as it allows you to work with complicated graphs. You can use pyplot in simple cases.

# %%
## OO style 

x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
## Pyplot method 

x = np.linspace(2, 20, 50)  # sample data 

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %% [markdown]
# Try to see the difference between how the codes are written mostly plt is replaced with ax

# %%
x = np.linspace(0, 10, 100)
fig, ax = plt.subplots()
ax.plot(x, x**2);          # default graph is a line graph

# %%
# scatter graph 
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));   # using exponential just for the illustration of scatter graph

# %%
# creating bar graph 
car_price = {
    "Car_A": 2000,
    "Car_B": 3000,
    "Car_c": 4000
}

fig, ax = plt.subplots()
ax.bar(car_price.keys(), car_price.values())
ax.set(title="Car Price Graph", xlabel="Cars", ylabel="Prices");   # notice this is also how you can set title and labels name

# %%
car_price = {
    "Car_A": 2000,
    "Car_B": 3000,
    "Car_c": 4000
}

fig, ax = plt.subplots()
ax.barh(list(car_price.keys()), list(car_price.values()))      # using barh to create horizontal graph and include them in a list 
ax.set(title="Car Price Graph", xlabel="Cars", ylabel="Prices");

# %%
# Creating a histogram 

x = np.random.randn(1000) 

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Subplots
# Subplots is nothing but multiple plots on the figure

# %%
# creating subplots using indices 
# you can also use ax1, ax2, ax3 etc instead of axes but axis is works just fine

fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(10, 5))        
ax[0, 0].plot(x, x**2)                                           # notice the value of x here is coming from our np.random.randn(1000) 
ax[0, 1].scatter(x, np.exp(x))                                   # same here for x 
ax[1, 0].bar(car_price.keys(), car_price.values())
ax[1, 1].barh(list(car_price.keys()), list(car_price.values()));

# %%
# using different axes 

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(ncols=2, nrows=2, figsize=(10, 5))         # make sure to include them in pairs otherwise you will get errors
ax1.plot(x, x**2)                                           # notice the value of x here is coming from our np.random.randn(1000) 
ax2.scatter(x, np.exp(x))                                   # same here for x 
ax3.bar(car_price.keys(), car_price.values())
ax4.barh(list(car_price.keys()), list(car_price.values()));

# %%
# in the previous lecture we talked about plotting using data in pandas. Here also we can do the same 
import pandas as pd 
time_series = pd.Series(np.random.randn(1000), index=pd.date_range('18/03/2023', periods=1000));
time_series
# Out:
# 2023-03-18    1.065294
# 2023-03-19   -0.807862
# 2023-03-20    0.939063
# 2023-03-21    0.489533
# 2023-03-22    0.415612
#                 ...
# 2025-12-07    1.986283
# 2025-12-08   -1.862774
# 2025-12-09    0.401208
# 2025-12-10    0.154955
# 2025-12-11    0.553353
# Freq: D, Length: 1000, dtype: float64

# %%
time_series.plot();

# %%
time_series.cumsum().plot()
# Out:
# <Axes: >

# %%
# importing our actual data 
iris = pd.read_csv("/content/drive/MyDrive/Data/Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Now let's create our plot 

fig, ax = plt.subplots(figsize=(10,5))
scatter = ax.plot(iris["PetalLengthCm"], iris["SepalLengthCm"])
ax.set(title="Sepal Lenghth And Petal length Comparison of different species", xlabel="PetalLengthCm", ylabel="SepalLengthCm");

# %%
# to save any graph you can simply download it by right clicking on the graph or use this function 

fig.savefig("/content/drive/MyDrive/Data/iris-graph.png")  # you can use the path name that you like

# %% [markdown]
# That's all for this notebook but it's not sufficient. You have basics in your hand now but we will try to explore the graph creation further as we start working on different problems. You don't need to master matplotlib completely. Just know that you can always look into documentation for further help. Here is a resources that I highly recommend reading.
#
# https://github.com/rougier/matplotlib-tutorial
#
# Just remmember that matplot lib is a tool we use for data science and machine learning and we don't need to master it but know how to find what we need and with time and practice you will become better with this. There is a lot you can do so don't waste your time learning everything. What's important is you being able to build projects and solve ml problems.
#
# Here is another resources that you must read: \
# https://www.kaggle.com/code/prashant111/matplotlib-tutorial-for-beginners
